# %%
# Import important Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset = pd.read_csv('C:/Users/gaura/OneDrive/Documents/Python/Housing_data.csv')

dataset
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave  None
# 1              1       SC20       RL           80     9600   Pave  None
# 2              2       SC60       RL           68    11250   Pave  None
# 3              3       SC70       RL           60     9550   Pave  None
# 4              4       SC60       RL           84    14260   Pave  None
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave  None
# 1456        1456       SC20       RL           85    13175   Pave  None
# 1457        1457       SC70       RL           66     9042   Pave  None
# 1458        1458       SC20       RL           68     9717   Pave  None
# 1459        1459       SC20       RL           75     9937   Pave  None
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
# See the data type of the datasets and null values in it
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Find columns with null values
null_values = dataset.isnull().sum()

# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

print(null_values)

# Reset the display options to their default values
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
# Unnamed: 0        0
# MSSubClass        0
# MSZoning          0
# LotFrontage       0
# LotArea           0
# Street            0
# Alley             0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        0
# MasVnrArea        0
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual          0
# BsmtCond          0
# BsmtExposure      0
# BsmtFinType1      0
# BsmtFinSF1        0
# BsmtFinType2      0
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# 1stFlrSF          0
# 2ndFlrSF          0
# ...

# %%
null_values = dataset.isnull().sum()

# Filter the null_values Series to include only columns with null values
columns_with_null = null_values[null_values > 0]

# Print the columns with null values
print(columns_with_null)
# Out:
# Electrical      1
# GarageYrBlt    81
# dtype: int64

# %%
columns_with_null1 = dataset[['Electrical','GarageYrBlt']]
columns_with_null1
# Out:
#      Electrical  GarageYrBlt
# 0         SBrkr       2003.0
# 1         SBrkr       1976.0
# 2         SBrkr       2001.0
# 3         SBrkr       1998.0
# 4         SBrkr       2000.0
# ...         ...          ...
# 1455      SBrkr       1999.0
# 1456      SBrkr       1978.0
# 1457      SBrkr       1941.0
# 1458      FuseA       1950.0
# 1459      SBrkr       1965.0
#
# [1460 rows x 2 columns]

# %%
unique_values = dataset['Electrical'].unique()
print(unique_values)
# Out:
# ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]

# %%
dataset['Electrical'].mode()
# Out:
# 0    SBrkr
# Name: Electrical, dtype: object

# %%
# Fill missing values in the 'Electrical' column with mode
dataset['Electrical'].fillna(dataset['Electrical'].mode()[0], inplace=True)

# Fill missing values in the 'GarageYrBlt' column with 0
dataset['GarageYrBlt'].fillna(0, inplace=True)

# Converting float value into integers
dataset['GarageYrBlt'] = pd.to_numeric(dataset['GarageYrBlt'], errors='coerce').astype('Int64')

# %%
null_values = dataset.isnull().sum()

# Filter the null_values Series to include only columns with null values
columns_with_null = null_values[null_values > 0]

# Print the columns with null values
print(columns_with_null)
# Out:
# Series([], dtype: int64)

# %%
dataset
# Out:
#       Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 0              0       SC60       RL           65     8450   Pave  None
# 1              1       SC20       RL           80     9600   Pave  None
# 2              2       SC60       RL           68    11250   Pave  None
# 3              3       SC70       RL           60     9550   Pave  None
# 4              4       SC60       RL           84    14260   Pave  None
# ...          ...        ...      ...          ...      ...    ...   ...
# 1455        1455       SC60       RL           62     7917   Pave  None
# 1456        1456       SC20       RL           85    13175   Pave  None
# 1457        1457       SC70       RL           66     9042   Pave  None
# 1458        1458       SC20       RL           68     9717   Pave  None
# 1459        1459       SC20       RL           75     9937   Pave  None
#
#      LotShape LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %% [markdown]
# ## Task 1
# ### Number of categorical features in dataset

# %%
# Find the columns
dataset.columns
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
# Number of categorical features

# Get the list of categorical columns
categorical_columns = dataset.select_dtypes(include=['object', 'category']).columns

# Find the number of categorical features
num_categorical_features = len(categorical_columns)

print(f'Number of categorical features: {num_categorical_features}')
# Out:
# Number of categorical features: 45

# %%
categorical_columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#        'Fence', 'MiscFeature', 'MoSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
categorical_features = dataset.select_dtypes(include=['object', 'category'])

print(f'Number of categorical features: {categorical_features}')
# Out:
# Number of categorical features:      MSSubClass MSZoning Street Alley LotShape LandContour Utilities  \
# 0          SC60       RL   Pave  None      Reg         Lvl    AllPub
# 1          SC20       RL   Pave  None      Reg         Lvl    AllPub
# 2          SC60       RL   Pave  None      IR1         Lvl    AllPub
# 3          SC70       RL   Pave  None      IR1         Lvl    AllPub
# 4          SC60       RL   Pave  None      IR1         Lvl    AllPub
# ...         ...      ...    ...   ...      ...         ...       ...
# 1455       SC60       RL   Pave  None      Reg         Lvl    AllPub
# 1456       SC20       RL   Pave  None      Reg         Lvl    AllPub
# 1457       SC70       RL   Pave  None      Reg         Lvl    AllPub
# 1458       SC20       RL   Pave  None      Reg         Lvl    AllPub
# 1459       SC20       RL   Pave  None      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageFinish GarageQual GarageCond  \
# ...

# %% [markdown]
# #### Based on analysis, there are 45 categorical features in dataset

# %% [markdown]
# ## Task 2

# %% [markdown]
# ## Univariate Analysis:
#
# Univariate analysis is the simplest form of analysis, and it can be done on both numerical and categorical features. Here's how to get started with univariate analysis:
#
# For numerical features, you can create summary statistics, histograms, box plots, and density plots to understand the distribution and patterns
#
# For categorical features, you can create bar plots to visualize the distribution of categories.

# %% [markdown]
# ### Univariate analysis for numerical features

# %%
# Summary statistics for a numerical variable
summary = dataset[['LotArea','OverallQual','YrSold','SalePrice']].describe()
print(summary)
# Out:
#              LotArea  OverallQual       YrSold      SalePrice
# count    1460.000000  1460.000000  1460.000000    1460.000000
# mean    10516.828082     6.099315  2007.815753  180921.195890
# std      9981.264932     1.382997     1.328095   79442.502883
# min      1300.000000     1.000000  2006.000000   34900.000000
# 25%      7553.500000     5.000000  2007.000000  129975.000000
# 50%      9478.500000     6.000000  2008.000000  163000.000000
# 75%     11601.500000     7.000000  2009.000000  214000.000000
# max    215245.000000    10.000000  2010.000000  755000.000000

# %%
numerical_columns = ['LotArea', 'OverallQual', 'YrSold', 'SalePrice']

# Create separate histograms for each numerical variable
for column in numerical_columns:
    plt.figure(figsize=(4, 3))
    sns.histplot(dataset[column], kde=True)
    plt.title(f"Histogram of {column}")
    plt.show()

# %% [markdown]
# ### According to the histograms;
# 1. Lot area of most of the houses fall within the 0 to 50000 square feet bucket
# 2. Overall quality of most of the houses is 5 i.e., average
# 3. There were lesser sale in the year of 2010 as compare to years 2006 to 2009
# 4. Sale price of most of the houses fall near 200,000.00

# %%
# Box plot for a numerical variable
plt.figure(figsize=(4, 3))
sns.boxplot(x=dataset['SalePrice'])
plt.title("Box Plot of Sale Price")
plt.show()

# %% [markdown]
# ### According to the Box Plot of sale price, there are so many outliers in sale price

# %%
from scipy.stats import gaussian_kde

# Create a density plot
density = gaussian_kde(dataset['YrSold'])
x_values = range(int(min(dataset['YrSold'])), int(max(dataset['YrSold'])) + 1)
y_values = density(x_values)

plt.plot(x_values, y_values)
plt.fill_between(x_values, y_values, alpha=0.2)
plt.title("Density Plot")
plt.xlabel("Year Sold")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ### According to the Density Plot of year sold, in 2009, highest number of units sold

# %% [markdown]
# ### Univariate analysis for categorical features

# %%
# Count the occurrences of each category
counts = {}
for item in dataset['MSZoning']:
    counts[item] = counts.get(item, 0) + 1

# Extract category names and counts
categories = list(counts.keys())
counts = list(counts.values())

# Create a bar plot
plt.bar(categories, counts)
plt.title("Bar Plot for MSZoning")
plt.xlabel("MSZoning")
plt.ylabel("Count")
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.show()

# %% [markdown]
# ### According to the Bar Plot of MSZoning, RL i.e., Residential Low-Density has the highest number of units

# %%
# Bar plot for a categorical variable
plt.figure(figsize=(4, 3))
sns.countplot(data=dataset, x='MSSubClass')
plt.title("Bar Plot of MSSubClass")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### According to the Bar Plot of MSSubClass, SC20 i.e., 1-STORY 1946 & NEWER ALL STYLES has the highest number of units

# %%
# Scatter plot for two numerical variables
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataset, x='YrSold', y='SalePrice')
plt.title("Scatter Plot of YrSold vs. SalePrice")
plt.show()

# %% [markdown]
# ### According to the Scatter plot for Sale Price and Year Sold, houses with highest price were sold in the year of 2007

# %% [markdown]
# ## Task 3

# %% [markdown]
# ## Multivariate Analysis:
#
# Multivariate analysis involves exploring relationships between multiple variables. You can use various plots and statistical tests to analyze these relationships.
#
# Here are some examples:
#
# For numeric vs. numeric relationships, you can create scatter plots, correlation matrices, and regression analysis.
#
# For numeric vs. categorical relationships, you can create box plots, violin plots, and t-tests.
#
# For categorical vs. categorical relationships, you can create contingency tables, chi-squared tests, and mosaic plots.

# %% [markdown]
# ### Multivariate analysis numeric vs. numeric relationships

# %%
plt.figure(figsize=(2, 2))
sns.heatmap(dataset[['YrSold','SalePrice']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### According to the Correlation Matrix of Year Sold and Sale Price, there is a no relationship between the Year Sold and Sale Price

# %%
import statsmodels.api as sm

# Sample data
x = dataset['YrSold']
y = dataset['SalePrice']

# Add a constant to the independent variable for the intercept term
x = sm.add_constant(x)

# Fit the regression model
model = sm.OLS(y, x).fit()

# Print the summary statistics
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.221
# Date:                Fri, 24 Nov 2023   Prob (F-statistic):              0.269
# Time:                        01:51:36   Log-Likelihood:                -18543.
# No. Observations:                1460   AIC:                         3.709e+04
# Df Residuals:                    1458   BIC:                         3.710e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.655e+06   3.14e+06      1.162      0.245   -2.51e+06    9.82e+06
# ...

# %% [markdown]
# ### Multivariate analysis numeric vs. categorical

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

# Create a box plot
sns.boxplot(x="MSSubClass", y="YrSold", data=dataset)
plt.title("Box Plot")

plt.show()

# %% [markdown]
# ### According to the Box Plot of Year Sold and MSSubClass, most type of the house were sold between 2007 and 2009 except SC190, SC160, SC75, SC180 and SC40. Sale of SC190 and SC75 happened between 2006 and 2008

# %%
# Create a violine plot
sns.violinplot(x=dataset["YrSold"], y=dataset["SalePrice"], data=dataset, hue=dataset["MSZoning"], split=False)
plt.title("Side-by-Side Violin Plot of Sale Price by Year Sold with MS Zoning")
plt.show()

# %% [markdown]
# ### According to the Violine Plot of Year Sold and SalePrice, there were no sale of MSZoning C (all) i.e., Commercial in the year of 2007

# %%
import scipy.stats as stats

# data for two independent groups
group1 = dataset['YearBuilt']
group2 = dataset['YrSold']

# Perform an independent t-test
t_stat, p_value = stats.ttest_ind(group1, group2)

# Print the results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")

# Determine if the difference is statistically significant (e.g., using a significance level of 0.05)
if p_value < 0.05:
    print("The means are significantly different.")
else:
    print("There is no significant difference between the means.")
# Out:
# T-statistic: -46.19247422487144
# P-value: 0.0
# The means are significantly different.

# %% [markdown]
# ## Task 4

# %% [markdown]
# ## Analysis of Data with Plots:
#
# You can use various types of plots to analyze your data, including:
#
# Box plots: Visualize the distribution of data and identify outliers.
#
# Scatter plots: Explore relationships between two numerical variables.
#
# Violin plots: Show the distribution of data across different categories.
#
# Bubble plots: Visualize three-dimensional data with the size and color of points.
#
# Histograms: Display the frequency distribution of a single numerical variable.
#
# Bar plots: Visualize the distribution of categories in a categorical variable.
#
# Kernel Density Estimation (KDE): Smoothed representation of data distribution.

# %%
# Create a Box plot for MS Zoning
plt.figure(figsize=(8, 6))
sns.boxplot(x=dataset['MSZoning'], y=dataset['SalePrice'])
plt.title("Box Plot of SalePrice by MSZoning")
plt.show()

# %% [markdown]
# ### Accoording to the Box Plot for MS Zoning and Sale Price, there are no outliers in sale price of C(all) i.e., commercial and RH i.e., Residential High-Density. There are more outliers in RL i.e., Residential Low-Density as compare to RM i.e., Residential Medium Density. There are very few outliers in FV i.e., Floating Village Residential

# %%
# Scatter plot for sale year built and year sold
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataset, x='YearBuilt', y='YrSold')
plt.title("Scatter Plot of YearBuilt vs. YrSold")
plt.show()

# %% [markdown]
# ### According to the Scatter plot for sale year built and year sold, most of houses were buit after 1990.

# %%
# Create a violin plot
sns.violinplot(x="MSZoning", y="SalePrice", data=dataset)
plt.show()

# %% [markdown]
# ### According to the Violin Plot, Sale price of MSZoning RL i.e., Residential Low-Density is highest and sale price of C(all) i.e., Commercial is lowest

# %%
# Create a bubble plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=dataset['MSSubClass'], y=dataset['MSZoning'], hue=dataset['OverallQual'], edgecolors='black', linewidth=1.5)

# Add labels and title
plt.title('Bubble Plot MSSubClass and MSZoning')
plt.xlabel('MSSubClass')
plt.ylabel('MSZoning')

# Show the plot
plt.show()

# %% [markdown]
# ### According to the Bubble Plot for MS Zoning and MS SubClass, overall quality of MSSubClass SC60 i.e., 2-STORY 1946 & NEWER in MSZoning FV i.e., Floating Village Residential is 10 i.e., very excellent. Overall quality of SC20 i.e., 1-STORY 1946 & NEWER ALL STYLES , SC120 i.e., 1-STORY PUD (Planned Unit Development) - 1946 & NEWER and SC160 i.e., 2-STORY PUD - 1946 & NEWER in FV is 7 i.e., good.

# %%
# Create a Histograms
plt.hist(dataset['SaleType'], bins=30, edgecolor='black')

# Add labels and title
plt.title('Histogram for Sale Type')
plt.xlabel('SaleType')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### According to the Histogram of Sale Type, majority of the sale type is WD i.e., Warranty Deed - Conventional

# %%
# Create a bar plot
plt.barh(dataset.index, dataset['SaleType'], color='skyblue')

# Add labels and title
plt.title('Bar Plot Sale Type')
plt.xlabel('Sale Type')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
# Create a Kernel Density Estimation (KDE) plot
sns.kdeplot(dataset['SalePrice'], shade=True, color='skyblue')

# Add labels and title
plt.title('Kernel Density Estimation (KDE) Plot')
plt.xlabel('SalePrice')
plt.ylabel('Density')

# Show the plot
plt.show()
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_7460\2806145488.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataset['SalePrice'], shade=True, color='skyblue')

# %% [markdown]
# ### According to KDE Plot for Sale Price, density of the houses whose sale price fall between 0 to 200000 is high.

# %%
plt.figure(figsize=(25, 25))
sns.heatmap(dataset.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_7460\840533080.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dataset.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### There are many variables that impact the house price. However, the variables that impact the house price most are;
# 1. Overall Quality of the house
# 2. Gr Living Area i.e., Above grade (ground) living area
# 3. Garage Cars: Size of garage in car capacity
# 4. Garage Area
